# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniGa-Mo/Trabajando_con_biblioteca_PANDAS_Python/blob/main/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PANDAS**

# %% [markdown]
# ## **Importando la base de datos**

# %%
import pandas as pd

url = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'

pd.read_csv(url)
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
pd.read_csv(url, sep=';')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos = pd.read_csv(url, sep=';')
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %%
datos.sample(10)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 19517             Departamento  Lomas de Chapultepec             3        1
# 1833              Departamento  Lomas de Chapultepec             2        1
# 23456             Departamento              Santa Fe             5        3
# 6574   Conjunto Comercial/Sala            La Condesa             0        7
# 16878             Tienda/Salón               Condesa             0        0
# 13998  Conjunto Comercial/Sala      Centro Histórico             0        0
# 2192   Conjunto Comercial/Sala      Centro Histórico             0        0
# 24889  Conjunto Comercial/Sala              Santa Fe             0        1
# 9734              Departamento            La Condesa             1        0
# 4065        Casa de Condominio              Santa Fe             5        3
#
#        Suites  Area    Valor  Condominio  Impuesto
# 19517       1   150  42000.0      6825.0   12673.5
# ...

# %% [markdown]
# Pandas ofrece diversas funciones para importar y exportar datos en diferentes formatos. Las principales funciones de Pandas para importar datos son las siguientes:
#
# **read_csv():** Esta función se utiliza para leer archivos CSV (Comma Separated Values), que son archivos de texto que contienen datos separados por comas. Es posible proporcionar varios parámetros para personalizar la lectura del CSV, como el delimitador, el encabezado, el tipo de codificación, entre otros.
#
# **read_excel():** Esta función se utiliza para leer archivos de Excel (.xls o .xlsx) y crear un DataFrame a partir de los datos.
#
# **read_json():** Esta función se utiliza para leer archivos JSON (JavaScript Object Notation), que son archivos de texto que contienen datos en formato de objeto JavaScript.
#
# **read_html():** Esta función se utiliza para leer tablas HTML, que son estructuras de datos organizadas en formato de tabla en una página web.
#
# **read_sql():** Esta función se utiliza para leer datos de una base de datos relacional, como MySQL, PostgreSQL y SQL Server. Pandas es capaz de importar datos de diferentes maneras, lo que permite ajustar parámetros como la consulta, el nombre de la tabla y el tipo de datos de las columnas.

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # **Exploración inicial de los datos**

# %% [markdown]
# ### Documentación de pandas
# [Biblioteca de Pandas](https://pandas.pydata.org/docs/)

# %%
# El atributo .shape en pandas se utiliza para conocer las dimensiones de un objeto tipo DataFrame o Series.

datos.shape
# Out:
# (25121, 9)

# %%
# En pandas, para ver los nombres de las columnas de un DataFrame,
# se utiliza el atributo .columns (no .columnas, ya que los nombres de los atributos están en inglés).

datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
# El atributo (o mejor dicho, método) .info() en pandas es una de las herramientas más útiles para
# inspeccionar rápidamente la estructura de un DataFrame.

datos.info
# Out:
# <bound method DataFrame.info of                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
# ...

# %%
datos['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[['Habitaciones', 'Valor']]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %% [markdown]
# # **Desafío: vamos a practicar**

# %%
# 1.- Importa el archivo alumnos.csv y almacena su contenido en un DataFrame de Pandas.
import pandas as pd

# Importamos la biblioteca csv.

# Url del archivo.
url2 = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'

# Lectura del archivo.
pd.read_csv(url2)
# Se guardan en una variable de memoria.
datos2 = pd.read_csv(url2)
datos2
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
# 2.- Visualiza las primeras 7 filas del DataFrame y las últimas 5.
# Primeras 7 filas.
datos2.head(7)
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True
# 5    Bruna    23   NaN    False
# 6  Daniela    21   7.0     True

# %%
# Ultimas 5 filas.
datos2.tail(5)
# Out:
#     Nombre  Edad  Nota   Aprobado
# 13  Miriam    25   9.0       True
# 14   Pablo    37   NaN      False
# 15  Milena    29   7.0       True
# 16   Lucas    33   NaN      False
# 17   Nadia    34   8.0  Verdadero

# %%
# 3.- Verifica la cantidad de filas y columnas en este DataFrame.
datos2.shape
# Out:
# (18, 4)

# %%
# 4.- Explora las columnas del DataFrame y analiza los tipos de datos presentes en cada columna.
datos2.columns
# Out:
# Index(['Nombre', 'Edad', 'Nota', 'Aprobado'], dtype='object')

# %%
# Seleccionar una columna
datos2['Nombre']

# Seleccionar múltiples columnas
datos2[['Edad', 'Nota']]

# Verificar los tipos de datos en cada columna
datos2.dtypes
# Out:
# Nombre       object
# Edad          int64
# Nota        float64
# Aprobado     object
# dtype: object

# %%
# Tipo de dato.
type(datos2)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# El método .describe() en pandas se usa para obtener un resumen estadístico de las columnas de un DataFrame.
# Es una herramienta clave en el análisis exploratorio de datos (EDA) porque te da una visión rápida de los valores numéricos o incluso categóricos de tus datos.
#
# Qué hace
#
# Por defecto, .describe() genera estadísticas solo de las columnas numéricas (int, float), mostrando:
#
# Estadístico	Descripción
#
# 1.   count	-> Cantidad de valores no nulos
# 2.   mean	-> Promedio
# 3.   std	-> Desviación estándar
# 4.   min	-> Valor mínimo
# 5.   25%	-> Percentil 25 (cuartil inferior)
# 6.   50%	-> Mediana
# 7.   75%	-> Percentil 75 (cuartil superior)
# 8.   max	-> Valor máximo

# %%
# Extra: Calcula algunas estadísticas descriptivas básicas de los datos en el DataFrame (media, desviación estándar, etc.). Pista: busca el método "describe".
datos2.describe()
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# ## Demandas de ML

# %% [markdown]
# ###¿Cuáles son los valores promedio de alquiler por tipo de propiedad?

# %%
# La función .mean() en pandas se usa para calcular la media aritmética (promedio) de los valores numéricos de una columna o de todo un DataFrame.

datos['Valor'].mean()
# Out:
# np.float64(36885.05048392878)

# %%
# El método .groupby() de pandas es uno de los más poderosos y usados para agrupar, resumir y analizar datos.
datos.groupby('Tipo').mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
datos.groupby('Tipo')['Valor'].mean()
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %% [markdown]
# | Sintaxis        | Tipo de objeto que devuelve | Resultado                     |
# | --------------- | --------------------------- | ----------------------------- |
# | `df['Valor']`   | **Series**                  | Columna individual (1D)       |
# | `df[['Valor']]` | **DataFrame**               | Subtabla (2D) con una columna |

# %%
datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
df_tipo_precio = datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor') #....sort_values('Valor', ascending=False), para invertir sentido.
df_tipo_precio.plot(kind='barh', figsize=(12, 8), color = 'green')
# Out:
# <Axes: ylabel='Tipo'>

# %%
datos['Tipo'].unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales = ['Conjunto Comercial/Sala',
                          'Edificio Completo', 'Tienda/Salón', 'Casa Comercial',
                          'Terreno Estándar', 'Cochera/Estacionamiento',
                          'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Hotel', 'Loteo/Condominio',
                          'Industria']

# %%
datos.query('@inmuebles_comerciales in Tipo')
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
datos.query('@inmuebles_comerciales not in Tipo')
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df = datos.query('@inmuebles_comerciales not in Tipo')
df.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %%
df_tipo_precio = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor') #....sort_values('Valor', ascending=False), para invertir sentido.
df_tipo_precio.plot(kind='barh', figsize=(12, 8), color = 'green')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ###**¿Cuál es el porcentaje de cada tipo de propiedad en nuestra base de datos?"**

# %%
df.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
df.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
porcentaje_tipo = df.Tipo.value_counts(normalize=True).to_frame()
porcentaje_tipo.plot(kind='bar', figsize=(12, 8), color = 'darkblue', xlabel='Tipo', ylabel='Porcentaje')
# Out:
# <Axes: xlabel='Tipo', ylabel='Porcentaje'>

# %%
df.query('Tipo == "Departamento"')
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df = df.query('Tipo == "Departamento"')
df.head(2)
# Out:
#            Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3  Departamento  Centro Histórico             1        0       0    15
# 4  Departamento         Del Valle             1        0       0    48
#
#     Valor  Condominio  Impuesto
# 3  2800.0      1365.0      70.0
# 4  2800.0       805.0       NaN

# %%
df.shape
# Out:
# (14764, 9)

# %% [markdown]
# #**Desafío: vamos a practicar**

# %%
# 1.- Calcular el promedio de habitaciones por departamento.
# Para calcular el promedio de habitaciones, podemos seleccionar la columna de interés y aplicar el método mean():
df['Habitaciones'].mean()
# Out:
# np.float64(2.5041994039555675)

# %%
df.groupby('Tipo')[['Habitaciones']].mean()
# Out:
#               Habitaciones
# Tipo
# Departamento      2.504199

# %%
# Verificar cuántas colonias únicas existen en nuestra base de datos.
df.Colonia.unique()
# Out:
# array(['Centro Histórico', 'Del Valle', 'Condesa', 'Santa Fe', 'Narvarte',
#        'Coyoacán', 'Roma', 'Lomas de Chapultepec',
#        'San Pedro de los Pinos', 'Polanco', 'San Ángel', 'San Jerónimo',
#        'Ciudad de los Deportes', 'Bosques de las Lomas', 'Juárez',
#        'Chapultepec', 'San Miguel Chapultepec', 'El Rosedal',
#        'Nueva Santa María', 'Arboledas', 'Villa de Cortés', 'Casa Blanca',
#        'Álvaro Obregón', 'Iztacalco', 'Mixcoac', 'Peralvillo', 'Napoles',
#        'Nativitas', 'Tlalpan', 'Roma Norte', 'San Rafael',
#        'Industrial Vallejo', 'La Condesa', 'Iztapalapa', 'Villa Coapa',
#        'Villa de Guadalupe', 'Lomas de Padierna', 'El Contadero',
#        'Las Águilas', 'Culhuacán CTM', 'El Arenal', 'San Sebastián',
#        'San Andrés Tetepilco', 'Loma Bonita', 'Santa Cruz Atoyac',
#        'El Rodeo', 'La Virgen', 'Lindavista', 'San José Insurgentes',
#        'Moctezuma', 'Atlampa', 'Del Valle Centro', 'Lindavista Sur',
# ...

# %%
"""
Una forma de verificar cuántos barrios únicos existen en la base de datos sería utilizando
el método unique(), que nos devolverá una lista con los barrios únicos.
Luego, podemos usar la función len para contar cuántos elementos hay en esa lista:

"""
len(df['Colonia'].unique())
# Out:
# 83

# %%
"""
Además, también podemos utilizar un método de Pandas que realiza directamente el
conteo de elementos únicos en una columna específica. Este método es nunique():

"""
df['Colonia'].nunique()
# Out:
# 83

# %%
# 3.- Analizar qué colonias tienen el promedio de alquiler más alto.
df2 = df.groupby('Colonia')[['Valor']].mean().sort_values('Valor', ascending=False)
df2.head(10)
# Out:
#                              Valor
# Colonia
# Los Alpes             54250.000000
# Bosques de Aragón     35948.718750
# Coyoacán              33205.218609
# Roma                  32530.388539
# Lomas de Chapultepec  30232.165189
# Bosques de las Lomas  28119.694274
# Santa Fe              19541.149118
# Tlalpan               17537.187500
# Ajusco                17150.000000
# Polanco               16683.013699

# %%
# 4.- Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.

df2.head(5).plot(kind='bar', figsize=(14, 10), color = 'purple', xlabel= 'Colonia', ylabel='Precio', title='Top 5 colonias con mayor promedio de alquiler')
# Out:
# <Axes: title={'center': 'Top 5 colonias con mayor promedio de alquiler'}, xlabel='Colonia', ylabel='Precio'>

# %% [markdown]
# # **Tratamiento de datos nulos**

# %%
# Identificación de datos nulos.
df.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# ...

# %%
# El metodo suma nos permite obtener la suma de los datos booleanos.
df.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %%
# Modificar datos nulos.
df.fillna(0)
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
# Para que se haga efectivo el cambio, se deben guardar en la variable.
df = df.fillna(0)
df.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# Existen varias formas de tratar datos nulos con Pandas. Algunas de las formas principales son:
#
# Eliminar los datos nulos: Es posible eliminar las filas o columnas que contienen valores nulos utilizando el método dropna(). Este método elimina todas las filas o columnas que tienen al menos un valor nulo.
#
# Llenar los datos nulos: Utilizando el método fillna(), podemos llenar los valores nulos con un valor específico. Además, también es posible utilizar argumentos específicos del método fillna(), como method="ffill" o method="bfill", para llenar los valores nulos con el valor anterior o posterior, respectivamente.
#
# Interpolar los datos nulos: Es posible utilizar el método interpolate() para llenar los valores nulos con valores interpolados, es decir, valores calculados a partir de los valores vecinos.

# %% [markdown]
# #**Remover registros inconcistentes**

# %%
df.query('Valor == 0 | Condominio == 0')
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# ...

# %%
df.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
df_remover = df.query('Valor == 0 | Condominio == 0').index

# %%
df.drop(df_remover,axis=0, inplace=True)

# %%
df.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([], dtype='int64')

# %%
df.head()
# Out:
#              Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3   Centro Histórico             1        0       0    15   2800.0
# 4          Del Valle             1        0       0    48   2800.0
# 8            Condesa             1        0       1    40   7000.0
# 10           Condesa             4        3       1   243  45500.0
# 13          Santa Fe             2        1       1    67   5950.0
#
#     Condominio  Impuesto
# 3       1365.0      70.0
# 4        805.0       0.0
# 8       1963.5     175.0
# 10      7000.0    2810.5
# 13      2061.5     514.5

# %%
#df.drop('Tipo', axis=1, inplace=True)
df.sample(10)
# Out:
#                   Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 7433              Polanco             3        2       0   180  15750.0
# 19083  Villa de Guadalupe             2        1       1    62   6300.0
# 12817            Narvarte             3        1       1    90   8750.0
# 24327             Condesa             4        2       2   250  33250.0
# 8691           La Condesa             2        0       0    85   7000.0
# 2952            Del Valle             3        0       0    95   8750.0
# 22752                Roma             2        1       1    79  15085.0
# 17612             Condesa             1        0       0    45   5950.0
# 21417            Santa Fe             4        4       4   397  31500.0
# 21022            Santa Fe             4        2       2   136  21000.0
#
#        Condominio  Impuesto
# 7433       7700.0    1225.0
# 19083      2100.0     220.5
# 12817      4725.0       0.0
# 24327      6167.0    2625.0
# 8691       2803.5     360.5
# ...

# %% [markdown]
# ##**Creando filtros**

# %% [markdown]
# ##1. Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200.

# %%
seleccion1 = df['Habitaciones'] == 1

# %%
type(seleccion1)
# Out:
# pandas.core.series.Series

# %%
df[seleccion1]
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 19                 Narvarte             1        0       0    48   2625.0
# 37         Centro Histórico             1        0       0    27   2625.0
# ...                     ...           ...      ...     ...   ...      ...
# 25090              Coyoacán             1        0       0    55   7000.0
# 25092              Santa Fe             1        1       0    62   5950.0
# 25100  Lomas de Chapultepec             1        1       1    50  15050.0
# 25103               Condesa             1        0       0    50   6825.0
# 25114              Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %%
seleccion2 = df['Valor'] < 4200
df[seleccion2]
# Out:
#                   Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3        Centro Histórico             1        0       0    15  2800.0
# 4               Del Valle             1        0       0    48  2800.0
# 19               Narvarte             1        0       0    48  2625.0
# 37       Centro Histórico             1        0       0    27  2625.0
# 61       Centro Histórico             1        1       0    37  3850.0
# ...                   ...           ...      ...     ...   ...     ...
# 25038  Villa de Guadalupe             2        1       0    50  2800.0
# 25051           Nativitas             2        1       0    62  3500.0
# 25065           Nativitas             2        1       0    50  3150.0
# 25095      Lindavista Sur             2        0       0    63  2800.0
# 25114            Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# ...

# %%
df[seleccion2].max()
# Out:
# Colonia         Álvaro Obregón
# Habitaciones                 3
# Garages                      2
# Suites                       2
# Area                       176
# Valor                   4025.0
# Condominio            152575.5
# Impuesto                6699.0
# dtype: object

# %%
filtro1 = seleccion1 & seleccion2
df[filtro1]
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
df1 = df[filtro1]

# %% [markdown]
# ##2. Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².

# %%
filtro2 =(df['Habitaciones'] >= 2) & (df['Valor'] < 10500) & (df['Area'] > 70)
df[filtro2]
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          0.0
# 21          0.0
# ...

# %%
df2 = df[filtro2]

# %% [markdown]
# ##**Guardando los datos**

# %%
df.to_csv('Inmuebles_ml.csv', index=False, sep=';')

# %%
df1.to_csv('Inmuebles_ml_filtro1.csv', index=False, sep=';')
df2.to_csv('Inmuebles_ml._filtro2csv', index=False, sep=';')

# %% [markdown]
# Pandas proporciona varios métodos para guardar archivos en diferentes formatos. Algunos ejemplos son:
#
# to_csv(): Guarda el DataFrame en un archivo CSV (Valores Separados por Comas).
#
# to_excel(): Guarda el DataFrame en un archivo de Excel.
#
# to_json(): Guarda el DataFrame en un archivo JSON (Notación de Objetos JavaScript).

# %% [markdown]
# ### Desafío: vamos a practicar

# %%
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
alum = pd.read_csv(url)
alum
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# ###1. Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.

# %%
# Verificamos si el data frame contiene datos nulos.
alum.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
alum.fillna(0)
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
alum1 = alum.fillna(0)
alum1.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        0
# Aprobado    0
# dtype: int64

# %% [markdown]
# ###2. Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.

# %%
alum1['Nombre']
# Out:
# 0      Alberto
# 1          Ana
# 2       Camila
# 3        David
# 4        Brian
# 5        Bruna
# 6      Daniela
# 7       Carlos
# 8       Alicia
# 9       Victor
# 10      Danilo
# 11     Ignacio
# 12    Stephany
# 13      Miriam
# 14       Pablo
# 15      Milena
# 16       Lucas
# 17       Nadia
# Name: Nombre, dtype: object

# %%
alum2 = alum1[~alum1['Nombre'].isin(['Alicia', 'Carlos'])]
alum2
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# ###3. Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.

# %%
filtrado1 = alum2['Nota'] >= 7.0

# %%
alum2[filtrado1]
# Out:
#       Nombre  Edad  Nota  Aprobado
# 0    Alberto    20   7.5      True
# 4      Brian    21  10.0      True
# 6    Daniela    21   7.0      True
# 12  Stephany    26  10.0      True
# 13    Miriam    25   9.0      True
# 15    Milena    29   7.0      True
# 17     Nadia    34   8.0      True

# %% [markdown]
# ###4. Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv".

# %%
alumnos_aprobados = alum2[filtrado1]
alumnos_aprobados.to_csv('alumnos_aprobados.csv', index=False, sep=';')

# %% [markdown]
# ### Extra: Al revisar las calificaciones de los estudiantes aprobados, notamos que algunas calificaciones eran incorrectas. Las estudiantes que obtuvieron una calificación de 7.0, en realidad tenían un punto extra que no se contabilizó. Por lo tanto, reemplaza las calificaciones de 7.0 en la base de datos por 8.0. Consejo: busca el método replace.

# %%
alumnos_aprobados
# Out:
#       Nombre  Edad  Nota  Aprobado
# 0    Alberto    20   7.5      True
# 4      Brian    21  10.0      True
# 6    Daniela    21   7.0      True
# 12  Stephany    26  10.0      True
# 13    Miriam    25   9.0      True
# 15    Milena    29   7.0      True
# 17     Nadia    34   8.0      True

# %%
alumnos_aprobados['Nota']
# Out:
# 0      7.5
# 4     10.0
# 6      7.0
# 12    10.0
# 13     9.0
# 15     7.0
# 17     8.0
# Name: Nota, dtype: float64

# %%
alumnos_aprobados['Nota'].replace(7.0, 8.0, inplace=False)
alumnos_aprobados
# Out:
#       Nombre  Edad  Nota  Aprobado
# 0    Alberto    20   7.5      True
# 4      Brian    21  10.0      True
# 6    Daniela    21   8.0      True
# 12  Stephany    26  10.0      True
# 13    Miriam    25   9.0      True
# 15    Milena    29   8.0      True
# 17     Nadia    34   8.0      True
